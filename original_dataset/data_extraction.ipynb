# %% [markdown]
# ### Surface_energy: with a unit of $eV/angstrom^2$
# ### Work_function: with a unit of $eV$

# %%
import json
import jsonpath

path = 'Mg_binary_intermetallics_surface_properties_data.json'
obj = json.load(open(path, 'r', encoding='utf-8'))
dataset = list(obj.values())

# %%
dataset[12]
# Out:
# {'Mongo_id': '620db5b01f9bc37c981e4513',
#  'Formula': 'PrMg3',
#  'Facet': '111_1',
#  'Surface_energy': 0.0200065,
#  'Work_function': 2.874,
#  'POSCAR': ['Pr5 Mg18',
#   '1.0',
#   '5.245270 0.000000 0.321005',
#   '2.612812 4.548194 0.321005',
#   '0.000000 0.000000 43.014709',
#   'Pr Mg',
#   '5 18',
#   'direct',
#   '0.587500 0.187500 0.287500 Pr',
#   '0.887500 0.487500 0.387500 Pr',
#   '0.187500 0.787500 0.487500 Pr',
#   '0.487500 0.087500 0.587500 Pr',
#   '0.787500 0.387500 0.687500 Pr',
#   '0.937500 0.537500 0.237500 Mg',
#   '0.612500 0.212500 0.212500 Mg',
#   '0.262500 0.862500 0.262500 Mg',
#   '0.237500 0.837500 0.337500 Mg',
#   '0.912500 0.512500 0.312500 Mg',
#   '0.562500 0.162500 0.362500 Mg',
#   '0.537500 0.137500 0.437500 Mg',
#   '0.212500 0.812500 0.412500 Mg',
#   '0.862500 0.462500 0.462500 Mg',
#   '0.837500 0.437500 0.537500 Mg',
#   '0.512500 0.112500 0.512500 Mg',
#   '0.162500 0.762500 0.562500 Mg',
#   '0.137500 0.737500 0.637500 Mg',
# ...
